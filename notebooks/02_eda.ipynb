# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
print(sys.executable)
# Out:
# d:\Data Science Projects\realestate-intelligence-platform\.venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from src.data_loader import DataLoader
from src.visualization import DataVisualizer

loader = DataLoader("../data/raw/kc_house_data.csv")
df = loader.load_data()

viz = DataVisualizer(df)

# %%
viz.histogram("price")

# %%
viz.boxplot("price")

# %%
price_stats = df["price"].describe()

print(price_stats)

print(f"Skewness : {df['price'].skew():.2f}")
print(f"Kurtosis : {df['price'].kurtosis():.2f}")
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64
# Skewness : 4.02
# Kurtosis : 34.59

# %%
df["log_price"] = np.log1p(df["price"])

# %%
viz = DataVisualizer(df)

# %%
viz.histogram("log_price")

# %%
viz.scatter("sqft_living", "price")

# %%
viz.bar_chart("bedrooms")

# %%
viz.correlation_heatmap()

# %%
viz.correlation_with_target("price")
# Out:
#                Correlation
# log_price         0.891654
# sqft_living       0.702035
# grade             0.667434
# sqft_above        0.605567
# sqft_living15     0.585379
# bathrooms         0.525138
# view              0.397293
# sqft_basement     0.323816
# bedrooms          0.308350
# lat               0.307003
# waterfront        0.266369
# floors            0.256794
# yr_renovated      0.126434
# sqft_lot          0.089661
# sqft_lot15        0.082447
# yr_built          0.054012
# condition         0.036362
# long              0.021626
# id               -0.016762
# zipcode          -0.053203

# %%
viz.pairplot(["price", "sqft_living", "grade", "bathrooms"])

# %%
df.nlargest(10, "price")[
    [
        "price",
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "grade",
        "zipcode",
    ]
]
# Out:
#           price  bedrooms  bathrooms  sqft_living  grade  zipcode
# 7252  7700000.0         6       8.00        12050     13    98102
# 3914  7062500.0         5       4.50        10040     11    98004
# 9254  6885000.0         6       7.75         9890     13    98039
# 4411  5570000.0         5       5.75         9200     13    98039
# 1448  5350000.0         5       5.00         8000     12    98004
# 1315  5300000.0         6       6.00         7390     12    98040
# 1164  5110800.0         5       5.25         8010     12    98033
# 8092  4668000.0         5       6.75         9640     12    98040
# 2626  4500000.0         5       5.50         6640     12    98155
# 8638  4489000.0         4       3.00         6430     12    98004

# %%
features = [
    "bedrooms",
    "bathrooms",
    "sqft_living",
    "sqft_lot",
    "floors",
    "grade",
    "condition",
]

# %%
for feature in features:
    viz.histogram(feature)
